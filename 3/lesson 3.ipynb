# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.1-cp39-cp39-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.1-cp39-cp39-win_amd64.whl (11.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'name':['אפרת','דבורי','חביבה','אילנה' ],'grate':['יא','יב','יא','ט'],'avgMarks':['85','78','90','100']}
sample = pd.DataFrame(data)
sample
# Out:
#     name grate avgMarks
# 0   אפרת    יא       85
# 1  דבורי    יב       78
# 2  חביבה    יא       90
# 3  אילנה     ט      100

# %%
data = {'name':['אפרת','דבורי','חביבה','אילנה' ],'grate':['יא','יב','יא','ט'],'avgMarks':['85','78','90','100']}
sample = pd.DataFrame(data)
df2 = sample.assign(address=['Delhi', 'Bangalore', 'Chennai', 'Patna'])
sample
# Out:
#     name grate avgMarks
# 0   אפרת    יא       85
# 1  דבורי    יב       78
# 2  חביבה    יא       90
# 3  אילנה     ט      100

# %% [markdown]
# ______________________________________________________________

# %%
cities = pd.read_csv('cities.csv')
cities
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
cities.isnull().sum().sum()
# Out:
# 0

# %%
result_df = cities.drop_duplicates()
cities
result_df
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
cities['LatD'].mean()
# Out:
# 38.8203125

# %%
cities.LatD = cities.LatD.fillna(0)

# %%
cities
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
cities.dropna(axis=0)
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
cities['LatD'].mean()
# Out:
# 38.8203125

# %%
cities['LatD'].max()
# Out:
# 50

# %%
cities['LatD'].min()
# Out:
# 26

# %%
cities['yachas']=cities['LatD']/cities['LatS']
cities
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State    yachas
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# 3           "Worcester"     MA  3.500000
# ...

# %%
cities.sort_valuse(by=['LatD'],descending=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3436\3050504174.py in ?()
# ----> 1 cities.sort_valuse(by=['LatD'],descending=True)
#
# c:\python39\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort_valuse'

# %%
cities[cities
['LatD'] == 41]
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW             City  \
# 0      41        5    59   "N"    80       39        0   "W"     "Youngstown"
# 11     41       15     0   "N"    77        0        0   "W"             null
# 18     41       25    11   "N"   122       23       23   "W"           "Weed"
# 25     41       32    59   "N"    73        3        0   "W"      "Waterbury"
# 27     41       50    59   "N"    79        8       23   "W"         "Warren"
# 49     41       39     0   "N"    83       32       24   "W"         "Toledo"
# 69     41       40    48   "N"    86       15        0   "W"     "South Bend"
# 79     41       24    35   "N"    75       40       11   "W"       "Scranton"
# 80     41       52    11   "N"   103       39       36   "W"    "Scottsbluff"
# 91     41       27     0   "N"    82       42       35   "W"       "Sandusky"
# 114    41       35    24   "N"   109       13       48   "W"   "Rock Springs"
# ...

# %%
simple2 = pd.DataFrame(cities)
simple2
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"    EW  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                    City  State    yachas
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# 3           "Worcester"     MA  3.500000
# ...
